# %%
#!pip install GetOldTweets3
# Out:
# Collecting GetOldTweets3
#   Downloading GetOldTweets3-0.0.11-py3-none-any.whl (13 kB)
# Collecting pyquery>=1.2.10
#   Downloading pyquery-1.4.1-py2.py3-none-any.whl (22 kB)
# Requirement already satisfied: lxml>=3.5.0 in c:\users\hocas\anaconda3\lib\site-packages (from GetOldTweets3) (4.5.0)
# Requirement already satisfied: cssselect>0.7.9 in c:\users\hocas\anaconda3\lib\site-packages (from pyquery>=1.2.10->GetOldTweets3) (1.1.0)
# Installing collected packages: pyquery, GetOldTweets3
# Successfully installed GetOldTweets3-0.0.11 pyquery-1.4.1

# %%
from bs4 import BeautifulSoup
import GetOldTweets3 as got
import pandas as pd
import time

# %% [markdown]
# ## 트위터 수집

# %%
def get_tweets(Username=None, 
               Since=None, Until=None, 
               QuerySearch=None, 
               Near=None, Within=None, 
               MaxTweets=None):
    
    # 트위터 수집 기준 정의
    '''
    # 특정 유저 아이디로 트윗 검색 (setUsername)
    # 기간 안의 트윗 검색 (setSince / setUntil)
    # 특정 검색어가 포함된 트윗 검색 (setQuerySearch)
    # 기준 위치를 설정하고 근처에서 생성된 트윗 검색 (setNear / setWithin)
    # 출력할 최대 트윗 수 지정 (setMaxTweets)
    '''
    tweetCriteria = got.manager.TweetCriteria()
    
    if Username: tweetCriteria.setUsername(Username)
    if Since: tweetCriteria.setSince(Since)
    if Until: tweetCriteria.setUntil(Until)
    if QuerySearch: tweetCriteria.setQuerySearch(QuerySearch)
    if Near: tweetCriteria.setNear(Near)
    if Within: tweetCriteria.setWithin(Within)
    if MaxTweets: tweetCriteria.setMaxTweets(MaxTweets)

    # 트위터 수집
    print("Collecting data start.. from {} to {}".format(Since, Until))
    
    tic = time.time()
    tweets = got.manager.TweetManager.getTweets(tweetCriteria)
    toc = time.time()

    print("Collecting data end.. {0:0.2f} Minutes".format((toc - tic)/60))
    print("=== Total num of tweets is {} ===".format(len(tweets)))
    
    return tweets

# %%
tweets = get_tweets('realDonaldTrump', MaxTweets=10)
# Out:
# Collecting data start.. from None to None
# Collecting data end.. 0.01 Minutes
# === Total num of tweets is 10 ===

# %% [markdown]
# # 수집된 데이터 정리

# %% [markdown]
# - 수집되지 않은 정보는, 아래 정보를 통해 따로 크롤링해서 수집해줘야 한다.
# - 트럼프가 리트윗한 트윗은 수집되지 않는다.
# - 스레드 형식으로 이어진 트윗은 수집되지 않는다.
# <br><br>
# ``` python
# tweets[2].username  # realDonaldTrump
# tweets[2].date     # datetime.datetime(2019, 9       날짜
# tweets[2].text     # 'Now the Fake News Media says'    내용
# tweets[2].favorites  # 31942                    좋아요
# tweets[2].retweets  # 8436                     리트윗 수
# tweets[2].replies   # 3906                     댓글
# tweets[2].permalink  # https://tw(..)              트위터 링크
# ```

# %%
def tweetsDataFrame(tweets):
    return pd.DataFrame(
            [[tweet.date.strftime("%Y%m%d"), 
              tweet.date
              .strftime("%H:%M:%S"),
              tweet.text, 
              tweet.favorites, 
              tweet.retweets, 
              tweet.replies, 
              tweet.permalink] for tweet in tweets],
        columns=['date', 'time', 'text', 'favorites', 'retweets', 'replies', 'permalink']
    ) 

# 94   20150105  04:36:42  " @Kbrozz26: @realDonaldTrump I don't watch a ...
# 95   20150105  04:35:26  " @bigdogg1974: @realDonaldTrump @Kateplusmy8 ...
# 96   20150105  04:05:16  Hope you liked it. Tune in tomorrow night at 8...
# 97   20150105  03:30:56  " @MNBosstom: @DonaldJTrumpJr @realDonaldTrump...
# 98   20150105  03:30:29  "@DerrickBolenVA: @realDonaldTrump has built u...
# 99   20150105  03:26:01  " @TEisen229: @realDonaldTrump great cast! Gir...
# 100  20150105  03:23:51  " @salans77: @realDonaldTrump great boardroom ...
# 101  20150105  03:00:53  " @SennieC: @realDonaldTrump all the athletes ...
# 102  20150105  02:04:30  " @princessrisssss: I am SOO super excited to ...
# 103  20150105  01:52:20  This is going to be a special season - truly g...
# 104  20150104  15:51:20  Everyone is asking me to cover The Apprentice ...
# 105  20150104  03:50:54  " @patjeanes: @realDonaldTrump Im sure the sho...
# 106  20150104  03:47:22  " @Cherylynn6464: @realDonaldTrump @Apprentice...
# 107  20150104  03:46:43  " @MIclimber: @realDonaldTrump look at alum @T...
# 108  20150104  03:43:20  " @yurdreamwoman: @ApprenticeNBC @realDonaldTr...
# 109  20150103  03:41:23  " @LmechX: @realDonaldTrump The Art of the Dea...
# 110  20150103  03:38:07  I will be commenting LIVE on Sunday night (9 t...
# 111  20150102  21:49:48  " @FREDOSANTANASS: @realDonaldTrump is a great...
# 112  20150102  21:47:21  "@StevenCena35: @realDonaldTrump look awesome ...
# 113  20150102  21:44:16  " @KdanielsK: @misstcassidy @realDonaldTrump @...
# 114  20150102  21:35:24  " @dungyots: . @realDonaldTrump with a solid c...
# 115  20150101  00:11:59  " @LLAnkers: DonaldTrump, it's a shame the lef...
# 116  20150101  00:11:12  " @ryanbushby: @realDonaldTrump i bet you have...
#
#      favorites  retweets  replies  \
# 0           20         9        4
# 1         2130      4480       53
# 2           48        93       18
# 3           71        31       21
# 4           34        25        2
# 5           92        32       24
# 6           30         9        4
# 7           30         7        9
# 8          171       180       92
# 9           18         7        2
# 10          42        18        7
# 11          15         6        2
# 12          23        12        4
# 13          21        12       15
# 14          46        22       10
# 15          80        34       51
# 16          49        38       19
# 17        4398      4811      219
# 18          74        45       34
# 19          41         7        4
# 20          33         5        3
# 21          35        14        5
# 22          38        28       13
# 23          48        34       29
# 24          34        18       15
# 25          55        29        7
# 26          26         8        1
# 27         792       636      220
# 28         123        77       41
# 29        2637      2447      126
# ..         ...       ...      ...
# 87          93        45       26
# 88         196        67       69
# 89          26         6        3
# 90          26        12       11
# 91          55        11        8
# 92         112        27       18
# 93          23         9        4
# 94          25         6        3
# 95          22         7        7
# 96         316        96       66
# 97          22         9        1
# 98          21         7        1
# 99          15         5        2
# 100         23        11        2
# 101         19         7        3
# 102         42        15        2
# 103        707       282      151
# 104        373       177      118
# 105         23        15        6
# 106         24        11        0
# 107         10         2        2
# 108         38        13        3
# 109         25        17        8
# 110        111        52       41
# 111         29        16        5
# 112         17         7        2
# 113         17         5        0
# 114        176        61       19
# 115         41        19       16
# 116         76        29       20
#
#                                              permalink
# 0    https://twitter.com/realDonaldTrump/status/561...
